# %%
import os

def print_tree(directory, indent=0):
    # List all files and directories in the current directory
    items = sorted(os.listdir(directory))
    for item in items:
        item_path = os.path.join(directory, item)
        if os.path.isdir(item_path):
            # Print directory name with indentation
            print("    " * indent + f" {item}")
            # Recursive call for subdirectories
            print_tree(item_path, indent + 1)
        else:
            # Print file name with indentation
            print("    " * indent + f" {item}")

# Specify the path to the 'vmd_output' folder
vmd_output_path = r"D:\AMRITA\Paper_SPS\Cardiorespiratory DB\vmd_output"
print(f"File structure of '{vmd_output_path}':")
print_tree(vmd_output_path)
# Out:
# File structure of 'D:\AMRITA\Paper_SPS\Cardiorespiratory DB\vmd_output':
#  ECG10
#      Breath_Hold
#          Subject_1.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_10.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_11.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_12.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#          Subject_13.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_14.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_15.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_16.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_17.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_18.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_19.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_2.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_20.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_21.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_22.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_23.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_24.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_25.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_26.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_27.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_28.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_29.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_3.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_30.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_31.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_32.0
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_33.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_34.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_35.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_36.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_37.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_38.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_39.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_4.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_40.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_41.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_42.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_43.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_44.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_45.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_46.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_47.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_48.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_49.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_5.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_50.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_6.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_7.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_8.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_9.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#      Deep_Breathing
#          Subject_1.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#          Subject_10.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_11.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#          Subject_12.0
#          Subject_13.0
#          Subject_14.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#          Subject_15.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#          Subject_16.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#          Subject_17.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#          Subject_18.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#          Subject_19.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#          Subject_2.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#          Subject_20.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#          Subject_21.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#          Subject_22.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#          Subject_23.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#          Subject_24.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#          Subject_25.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#          Subject_26.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#          Subject_27.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#          Subject_28.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#          Subject_29.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#          Subject_3.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#          Subject_30.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#          Subject_31.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#          Subject_32.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#          Subject_33.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#          Subject_34.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#          Subject_35.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#          Subject_36.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#          Subject_37.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#          Subject_38.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#          Subject_39.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#          Subject_4.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#          Subject_40.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#          Subject_41.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#          Subject_42.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#          Subject_43.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#          Subject_44.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#          Subject_45.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#          Subject_46.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#          Subject_47.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#          Subject_48.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#          Subject_49.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#          Subject_5.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#          Subject_50.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#          Subject_6.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#          Subject_7.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#          Subject_8.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#          Subject_9.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#      Normal_Breathing
#          Subject_1.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#              Segment_6_vmd.npy
#              Segment_6_vmd.png
#              Segment_7_vmd.npy
#              Segment_7_vmd.png
#          Subject_10.0
#              Segment_10_vmd.npy
#              Segment_10_vmd.png
#              Segment_11_vmd.npy
#              Segment_11_vmd.png
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#              Segment_6_vmd.npy
#              Segment_6_vmd.png
#              Segment_7_vmd.npy
#              Segment_7_vmd.png
#              Segment_8_vmd.npy
#              Segment_8_vmd.png
#              Segment_9_vmd.npy
#              Segment_9_vmd.png
#          Subject_11.0
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#              Segment_6_vmd.npy
#              Segment_6_vmd.png
#              Segment_7_vmd.npy
#              Segment_7_vmd.png
#              Segment_8_vmd.npy
#              Segment_8_vmd.png
#              Segment_9_vmd.npy
#              Segment_9_vmd.png
#          Subject_8.0
#              Segment_10_vmd.npy
#              Segment_10_vmd.png
#              Segment_11_vmd.npy
#              Segment_11_vmd.png
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#              Segment_6_vmd.npy
#              Segment_6_vmd.png
#              Segment_7_vmd.npy
#              Segment_7_vmd.png
#              Segment_8_vmd.npy
#              Segment_8_vmd.png
#              Segment_9_vmd.npy
#              Segment_9_vmd.png
#          Subject_9.0
#              Segment_10_vmd.npy
#              Segment_10_vmd.png
#              Segment_11_vmd.npy
#              Segment_11_vmd.png
#              Segment_1_vmd.npy
#              Segment_1_vmd.png
#              Segment_2_vmd.npy
#              Segment_2_vmd.png
#              Segment_3_vmd.npy
#              Segment_3_vmd.png
#              Segment_4_vmd.npy
#              Segment_4_vmd.png
#              Segment_5_vmd.npy
#              Segment_5_vmd.png
#              Segment_6_vmd.npy
#              Segment_6_vmd.png
#              Segment_7_vmd.npy
#              Segment_7_vmd.png
#              Segment_8_vmd.npy
#              Segment_8_vmd.png
#              Segment_9_vmd.npy
#              Segment_9_vmd.png

# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader
import torch

# %%
# Function to load all signals and labels from multiple datasets
def load_multiple_datasets(base_dir):
    signals = []
    labels = []
    label_map = {"Breath_Hold": 0, "Normal_Breathing": 1, "Deep_Breathing": 2}  # Adjust as needed

    # Traverse each dataset (e.g., ECG6, ECG10)
    for dataset_name in os.listdir(base_dir):
        dataset_dir = os.path.join(base_dir, dataset_name)
        if not os.path.isdir(dataset_dir):
            continue

        # Traverse conditions within each dataset (e.g., Breath_Hold, Deep_Breathing)
        for label_name in os.listdir(dataset_dir):
            label_dir = os.path.join(dataset_dir, label_name)
            if not os.path.isdir(label_dir):
                continue

            # Traverse .npy files for each condition
            for root, _, files in os.walk(label_dir):
                for file in files:
                    if file.endswith(".npy"):
                        file_path = os.path.join(root, file)
                        try:
                            signal = np.load(file_path)
                            signals.append(signal)  # Keep signals as a list
                            labels.append(label_map[label_name])
                        except Exception as e:
                            print(f"Error loading file {file_path}: {e}")
                            continue

    if len(signals) == 0 or len(labels) == 0:
        print("No data loaded. Please check the data directory and ensure it contains .npy files.")
        raise ValueError("No data loaded. Please check the data directory and ensure it contains .npy files.")

    return signals, labels  # Return lists for variable-length handling


# Define a custom dataset class
class SignalDataset(Dataset):
    def __init__(self, signals, labels):
        self.signals = signals
        self.labels = labels

    def __len__(self):
        return len(self.signals)

    def __getitem__(self, idx):
        signal = torch.tensor(self.signals[idx], dtype=torch.float32)  # Convert to tensor
        label = torch.tensor(self.labels[idx], dtype=torch.long)
        return signal, label


from torch.nn.utils.rnn import pad_sequence

# Custom collate function for variable-length signals
def collate_fn(batch):
    signals, labels = zip(*batch)  # Separate signals and labels
    padded_signals = pad_sequence([torch.tensor(s, dtype=torch.float32) for s in signals], batch_first=True)
    return padded_signals, torch.tensor(labels)


# Main code
base_dir = r"D:\AMRITA\Paper_SPS\Cardiorespiratory DB\vmd_output"  # Base directory containing ECG6, ECG10, etc.

# Load data from all datasets
signals, labels = load_multiple_datasets(base_dir)

# Confirm data is loaded
print(f"Loaded {len(signals)} signals and {len(labels)} labels.")

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(signals, labels, test_size=0.2, random_state=42)

# Create Dataset objects
train_dataset = SignalDataset(X_train, y_train)
test_dataset = SignalDataset(X_test, y_test)

# Create DataLoader objects
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, collate_fn=collate_fn)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, collate_fn=collate_fn)

# Verify shapes
for batch_idx, (signals_batch, labels_batch) in enumerate(train_loader):
    print(f"Batch {batch_idx}:")
    print(f"Number of signals: {len(signals_batch)}")
    print(f"Shapes of signals in this batch: {[s.shape for s in signals_batch]}")
    print(f"Labels batch shape: {labels_batch.shape}")
    break  # Inspect one batch

# %%
print(labels)

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
from tqdm import tqdm

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import classification_report, accuracy_score
from tqdm import tqdm

# Preprocessing Function: Normalize signals
def preprocess_signals(signals):
    normalized_signals = []
    for signal in signals:
        if np.std(signal) != 0:  # Avoid division by zero
            signal = (signal - np.mean(signal)) / np.std(signal)
        else:
            signal = signal - np.mean(signal)  # If variance is zero, just subtract the mean
        normalized_signals.append(signal)
    return normalized_signals

# 1D CNN Model
class RespiratorySignalClassifier(nn.Module):
    def __init__(self):
        super(RespiratorySignalClassifier, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=16, kernel_size=5, stride=1, padding=2)
        self.conv2 = nn.Conv1d(in_channels=16, out_channels=32, kernel_size=5, stride=1, padding=2)
        self.conv3 = nn.Conv1d(in_channels=32, out_channels=64, kernel_size=5, stride=1, padding=2)
        self.pool = nn.MaxPool1d(kernel_size=2, stride=2)
        self.fc1 = None  # Placeholder for dynamically determined input size
        self.fc2 = nn.Linear(128, 3)  # 3 output classes
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        x = self.pool(self.relu(self.conv1(x)))
        x = self.pool(self.relu(self.conv2(x)))
        x = self.pool(self.relu(self.conv3(x)))
        if self.fc1 is None:  # Dynamically initialize fc1 during the first forward pass
            in_features = x.size(1) * x.size(2)
            self.fc1 = nn.Linear(in_features, 128).to(x.device)
        x = x.view(x.size(0), -1)  # Flatten
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# Training Function
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=10):
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        # Training loop
        train_loop = tqdm(train_loader, desc=f"Epoch {epoch + 1}/{num_epochs} - Training", leave=False)
        for signals_batch, labels_batch in train_loop:
            try:
                # Move padded tensor to the device
                signals_batch = signals_batch.to(device, dtype=torch.float32).unsqueeze(1)  # Add channel dimension
                labels_batch = labels_batch.to(device, dtype=torch.long)

                optimizer.zero_grad()
                outputs = model(signals_batch)
                loss = criterion(outputs, labels_batch)
                loss.backward()
                optimizer.step()

                running_loss += loss.item()
                train_loop.set_postfix(loss=loss.item())
            except Exception as e:
                print(f"Error in training loop: {e}")


        # Validation loop
        val_loss, val_acc = validate_model(model, val_loader, criterion)
        print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {running_loss / len(train_loader):.4f}, "
              f"Val Loss: {val_loss:.4f}, Val Accuracy: {val_acc:.4f}")

    return model

# Validation Function
def validate_model(model, val_loader, criterion):
    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0

    val_loop = tqdm(val_loader, desc="Validating", leave=False)
    with torch.no_grad():
        for signals_batch, labels_batch in val_loop:
            try:
                signals_batch = signals_batch.to(device, dtype=torch.float32).unsqueeze(1)  # Add channel dimension
                labels_batch = labels_batch.to(device, dtype=torch.long)

                outputs = model(signals_batch)
                loss = criterion(outputs, labels_batch)
                val_loss += loss.item()

                _, predicted = torch.max(outputs, 1)
                total += labels_batch.size(0)
                correct += (predicted == labels_batch).sum().item()

                val_loop.set_postfix(loss=loss.item())
            except Exception as e:
                print(f"Error in validation loop: {e}")

    val_acc = correct / total
    return val_loss / len(val_loader), val_acc

# Device Setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define model, criterion, and optimizer
model = RespiratorySignalClassifier().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Train the model
trained_model = train_model(model, train_loader, test_loader, criterion, optimizer, num_epochs=20)

# Test the model
model.eval()
all_predictions = []
all_labels = []
with torch.no_grad():
    for signals_batch, labels_batch in tqdm(test_loader, desc="Testing"):
        signals_batch = signals_batch.to(device, dtype=torch.float32).unsqueeze(1)  # Add channel dimension
        labels_batch = labels_batch.to(device, dtype=torch.long)

        outputs = model(signals_batch)
        _, predicted = torch.max(outputs, 1)
        all_predictions.extend(predicted.cpu().numpy())
        all_labels.extend(labels_batch.cpu().numpy())

# Evaluate performance
print(classification_report(all_labels, all_predictions, target_names=["Breath_Hold", "Normal_Breathing", "Deep_Breathing"]))
print(f"Test Accuracy: {accuracy_score(all_labels, all_predictions):.4f}")
# Out:
# Epoch 1/20 - Training:   0%|          | 2/996 [00:00<01:12, 13.69it/s]
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Epoch 1/20 - Training:   1%|          | 9/996 [00:00<00:40, 24.55it/s]
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Epoch 1/20 - Training:   2%|▏         | 16/996 [00:00<00:42, 23.07it/s]
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Epoch 1/20 - Training:   2%|▏         | 19/996 [00:00<00:41, 23.27it/s]
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Epoch 1/20 - Training:   3%|▎         | 25/996 [00:01<00:43, 22.21it/s]
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Epoch 1/20 - Training:   3%|▎         | 28/996 [00:01<00:41, 23.26it/s]
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Epoch 1/20 - Training:   3%|▎         | 34/996 [00:01<00:52, 18.44it/s]
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Epoch 1/20 - Training:   4%|▎         | 36/996 [00:01<00:58, 16.43it/s]
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Epoch 1/20 - Training:   4%|▍         | 40/996 [00:02<01:15, 12.67it/s]
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Epoch 1/20 - Training:   4%|▍         | 42/996 [00:02<01:12, 13.16it/s]
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Epoch 1/20 - Training:   5%|▍         | 47/996 [00:02<01:06, 14.30it/s]
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Epoch 1/20 - Training:   5%|▍         | 49/996 [00:02<01:05, 14.47it/s]
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Epoch 1/20 - Training:   6%|▌         | 55/996 [00:03<01:04, 14.56it/s]
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Epoch 1/20 - Training:   6%|▌         | 59/996 [00:03<00:57, 16.21it/s]
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Epoch 1/20 - Training:   6%|▌         | 61/996 [00:03<00:56, 16.60it/s]
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Epoch 1/20 - Training:   7%|▋         | 65/996 [00:04<01:20, 11.58it/s]
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Epoch 1/20 - Training:   7%|▋         | 67/996 [00:04<01:26, 10.80it/s]
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Epoch 1/20 - Training:   7%|▋         | 69/996 [00:04<01:27, 10.54it/s]
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Epoch 1/20 - Training:   7%|▋         | 73/996 [00:04<01:13, 12.60it/s]
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# Error in training loop: 'list' object has no attribute 'to'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 117
#     114 optimizer = optim.Adam(model.parameters(), lr=0.001)
#     116 # Train the model
# --> 117 trained_model = train_model(model, train_loader, test_loader, criterion, optimizer, num_epochs=20)
#     119 # Test the model
#     120 model.eval()
#
# Cell In[4], line 54, in train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs)
#      52 # Training loop
#      53 train_loop = tqdm(train_loader, desc=f"Epoch {epoch + 1}/{num_epochs} - Training", leave=False)
# ---> 54 for signals_batch, labels_batch in train_loop:
#      55     try:
#      56         # Move padded tensor to the device
#      57         signals_batch = signals_batch.to(device, dtype=torch.float32).unsqueeze(1)  # Add channel dimension
#
# File c:\Users\shrut\anaconda3\envs\torchenv\Lib\site-packages\tqdm\std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File c:\Users\shrut\anaconda3\envs\torchenv\Lib\site-packages\torch\utils\data\dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File c:\Users\shrut\anaconda3\envs\torchenv\Lib\site-packages\torch\utils\data\dataloader.py:673, in _SingleProcessDataLoaderIter._next_data(self)
#     671 def _next_data(self):
#     672     index = self._next_index()  # may raise StopIteration
# --> 673     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     674     if self._pin_memory:
#     675         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\shrut\anaconda3\envs\torchenv\Lib\site-packages\torch\utils\data\_utils\fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# Cell In[2], line 49, in SignalDataset.__getitem__(self, idx)
#      48 def __getitem__(self, idx):
# ---> 49     signal = torch.tensor(self.signals[idx], dtype=torch.float32)  # Convert to tensor
#      50     label = torch.tensor(self.labels[idx], dtype=torch.long)
#      51     return signal, label
#
# KeyboardInterrupt:
